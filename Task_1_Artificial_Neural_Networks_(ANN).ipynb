# %% [markdown]
# # Exam on Artificial Neural Networks (ANN)
#
# Welcome the Artificial Neural Networks (ANN) practical exam. In this exam, you will work on a classification task to predict the outcome of incidents involving buses. You are provided with a dataset that records breakdowns and delays in bus operations. Your task is to build, train, and evaluate an ANN model.
#
# ---
#
# ## Dataset Overview
#
# ### **Dataset:**
# * Just run the command under the `Load Data` section to get the data downloaded and unzipped or you can access it [here](https://drive.google.com/file/d/1Flvj3qDkV2rPw7GGi5zOR-WGJgEBtRk-/view?usp=sharing)
#
# ### **Dataset Name:** Bus Breakdown and Delays
#
# ### **Description:**
# The dataset contains records of incidents involving buses that were either running late or experienced a breakdown. Your task is to predict whether the bus was delayed or had a breakdown based on the features provided.
#
# ### **Features:**
# The dataset contains the following columns:
#
# - `School_Year`
# - `Busbreakdown_ID`
# - `Run_Type`
# - `Bus_No`
# - `Route_Number`
# - `Reason`
# - `Schools_Serviced`
# - `Occurred_On`
# - `Created_On`
# - `Boro`
# - `Bus_Company_Name`
# - `How_Long_Delayed`
# - `Number_Of_Students_On_The_Bus`
# - `Has_Contractor_Notified_Schools`
# - `Has_Contractor_Notified_Parents`
# - `Have_You_Alerted_OPT`
# - `Informed_On`
# - `Incident_Number`
# - `Last_Updated_On`
# - `Breakdown_or_Running_Late` (Target Column)
# - `School_Age_or_PreK`

# %% [markdown]
# ## Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# This could include:
# * **Inspect the dataset**
#
# * **Dataset structure**
#
# * **Summary statistics**
#
# * **Check for missing values**
#
# * **Distribution of features**
#
# * **Categorical feature analysis**
#
# * **Correlation matrix**
#
# * **Outlier detection**
#
# And add more as needed!

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset2/Bus_Breakdown_and_Delays.csv')
df
# Out:
#        School_Year  Busbreakdown_ID             Run_Type  Bus_No Route_Number  \
# 0        2015-2016          1224901             Pre-K/EI     811            1
# 1        2015-2016          1225098             Pre-K/EI    9302            1
# 2        2015-2016          1215800             Pre-K/EI     358            2
# 3        2015-2016          1215511             Pre-K/EI     331            2
# 4        2015-2016          1215828             Pre-K/EI     332            2
# ...            ...              ...                  ...     ...          ...
# 147967   2016-2017          1338452             Pre-K/EI    9345            2
# 147968   2016-2017          1341521             Pre-K/EI    0001            5
# 147969   2016-2017          1353044    Special Ed PM Run  GC0112         X928
# 147970   2016-2017          1353045    Special Ed PM Run   5525D         Q920
# 147971   2016-2017          1353046  Project Read PM Run    2530         K617
#
#                Reason Schools_Serviced             Occurred_On  \
# 0               Other             C353  10/26/2015 08:30:00 AM
# 1       Heavy Traffic             C814  10/27/2015 07:10:00 AM
# 2       Heavy Traffic             C195  09/18/2015 07:36:00 AM
# 3               Other             C178  09/17/2015 08:08:00 AM
# 4               Other             S176  09/18/2015 07:39:00 AM
# ...               ...              ...                     ...
# 147967  Heavy Traffic             C530  04/05/2017 08:00:00 AM
# 147968  Heavy Traffic             C579  04/24/2017 07:42:00 AM
# 147969  Heavy Traffic            09003  05/25/2017 04:22:00 PM
# 147970    Won`t Start            24457  05/25/2017 04:27:00 PM
# 147971          Other            21436  05/25/2017 04:36:00 PM
#
#                     Created_On      Boro  ... How_Long_Delayed  \
# 0       10/26/2015 08:40:00 AM     Bronx  ...        10MINUTES
# 1       10/27/2015 07:11:00 AM     Bronx  ...       25 MINUTES
# 2       09/18/2015 07:38:00 AM     Bronx  ...       15 MINUTES
# 3       09/17/2015 08:12:00 AM     Bronx  ...       10 minutes
# 4       09/18/2015 07:45:00 AM     Bronx  ...        10MINUTES
# ...                        ...       ...  ...              ...
# 147967  04/05/2017 08:10:00 AM     Bronx  ...            15-20
# 147968  04/24/2017 07:44:00 AM     Bronx  ...          20 MINS
# 147969  05/25/2017 04:28:00 PM     Bronx  ...        20-25MINS
# 147970  05/25/2017 04:30:00 PM    Queens  ...              NaN
# 147971  05/25/2017 04:37:00 PM  Brooklyn  ...            45min
#
#        Number_Of_Students_On_The_Bus  Has_Contractor_Notified_Schools  \
# 0                                  5                              Yes
# 1                                  3                              Yes
# 2                                 12                              Yes
# 3                                 11                              Yes
# 4                                 12                              Yes
# ...                              ...                              ...
# 147967                             7                              Yes
# 147968                             0                              Yes
# 147969                             0                              Yes
# 147970                             0                              Yes
# 147971                             7                              Yes
#
#        Has_Contractor_Notified_Parents Have_You_Alerted_OPT  \
# 0                                  Yes                   No
# 1                                  Yes                   No
# 2                                  Yes                  Yes
# 3                                  Yes                  Yes
# 4                                  Yes                   No
# ...                                ...                  ...
# 147967                             Yes                   No
# 147968                             Yes                   No
# 147969                             Yes                  Yes
# 147970                             Yes                   No
# 147971                             Yes                  Yes
#
#                    Informed_On Incident_Number         Last_Updated_On  \
# 0       10/26/2015 08:40:00 AM             NaN  10/26/2015 08:40:39 AM
# 1       10/27/2015 07:11:00 AM             NaN  10/27/2015 07:11:22 AM
# 2       09/18/2015 07:38:00 AM             NaN  09/18/2015 07:38:44 AM
# 3       09/17/2015 08:12:00 AM             NaN  09/17/2015 08:12:08 AM
# 4       09/18/2015 07:45:00 AM             NaN  09/18/2015 07:56:40 AM
# ...                        ...             ...                     ...
# 147967  04/05/2017 08:10:00 AM             NaN  04/05/2017 08:10:15 AM
# 147968  04/24/2017 07:44:00 AM             NaN  04/24/2017 07:44:15 AM
# 147969  05/25/2017 04:28:00 PM        90323827  05/25/2017 04:34:36 PM
# 147970  05/25/2017 04:30:00 PM             NaN  05/25/2017 04:30:07 PM
# 147971  05/25/2017 04:37:00 PM             NaN  05/25/2017 04:37:37 PM
#
#        Breakdown_or_Running_Late School_Age_or_PreK
# 0                   Running Late              Pre-K
# 1                   Running Late              Pre-K
# 2                   Running Late              Pre-K
# 3                   Running Late              Pre-K
# 4                   Running Late              Pre-K
# ...                          ...                ...
# 147967              Running Late              Pre-K
# 147968              Running Late              Pre-K
# 147969              Running Late         School-Age
# 147970                 Breakdown         School-Age
# 147971              Running Late         School-Age
#
# [147972 rows x 21 columns]

# %% [markdown]
# # **Inspect the dataset**

# %% [markdown]
# # **Dataset structure**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147972 entries, 0 to 147971
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   School_Year                      147972 non-null  object
#  1   Busbreakdown_ID                  147972 non-null  int64
#  2   Run_Type                         147883 non-null  object
#  3   Bus_No                           147972 non-null  object
#  4   Route_Number                     147884 non-null  object
#  5   Reason                           147870 non-null  object
#  6   Schools_Serviced                 147972 non-null  object
#  7   Occurred_On                      147972 non-null  object
#  8   Created_On                       147972 non-null  object
#  9   Boro                             141654 non-null  object
#  10  Bus_Company_Name                 147972 non-null  object
#  11  How_Long_Delayed                 126342 non-null  object
#  12  Number_Of_Students_On_The_Bus    147972 non-null  int64
#  13  Has_Contractor_Notified_Schools  147972 non-null  object
#  14  Has_Contractor_Notified_Parents  147972 non-null  object
#  15  Have_You_Alerted_OPT             147972 non-null  object
#  16  Informed_On                      147972 non-null  object
#  17  Incident_Number                  5632 non-null    object
#  18  Last_Updated_On                  147972 non-null  object
#  19  Breakdown_or_Running_Late        147972 non-null  object
#  20  School_Age_or_PreK               147972 non-null  object
# dtypes: int64(2), object(19)
# memory usage: 23.7+ MB

# %% [markdown]
# # **Summary statistics**

# %%
df.describe()
# Out:
#        Busbreakdown_ID  Number_Of_Students_On_The_Bus
# count     1.479720e+05                  147972.000000
# mean      1.287779e+06                       3.590071
# std       4.324338e+04                      55.365859
# min       1.212681e+06                       0.000000
# 25%       1.250438e+06                       0.000000
# 50%       1.287844e+06                       0.000000
# 75%       1.325191e+06                       4.000000
# max       1.362605e+06                    9007.000000

# %%
df['Breakdown_or_Running_Late'].value_counts()
# Out:
# Breakdown_or_Running_Late
# Running Late    130857
# Breakdown        17115
# Name: count, dtype: int64

# %% [markdown]
# # **Check for missing values and dublication**

# %%
df.isnull().sum()
# Out:
# School_Year                             0
# Busbreakdown_ID                         0
# Run_Type                               89
# Bus_No                                  0
# Route_Number                           88
# Reason                                102
# Schools_Serviced                        0
# Occurred_On                             0
# Created_On                              0
# Boro                                 6318
# Bus_Company_Name                        0
# How_Long_Delayed                    21630
# Number_Of_Students_On_The_Bus           0
# Has_Contractor_Notified_Schools         0
# Has_Contractor_Notified_Parents         0
# Have_You_Alerted_OPT                    0
# Informed_On                             0
# Incident_Number                    142340
# Last_Updated_On                         0
# Breakdown_or_Running_Late               0
# School_Age_or_PreK                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #**Correlation matrix**

# %%
numiric_value=df[['Busbreakdown_ID','Number_Of_Students_On_The_Bus']].corr()

plt.figure(figsize=(6,8))
sns.heatmap(numiric_value,annot=True)
plt.show()

# %% [markdown]
# # **Distribution of features**

# %%
seniot_counts=df['Breakdown_or_Running_Late'].value_counts()

fig, ax = plt.subplots()
ax.bar(seniot_counts.index,seniot_counts.values,color=['skyblue','orange'])
ax.set_xticklabels(['Running Late','Breakdown '])
ax.set_xticks([0,1])

plt.show()
# Out:
# <ipython-input-62-646fd27b998d>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Running Late','Breakdown '])

# %%
df.describe()
# Out:
#        Busbreakdown_ID  Number_Of_Students_On_The_Bus
# count     1.479720e+05                  147972.000000
# mean      1.287779e+06                       3.590071
# std       4.324338e+04                      55.365859
# min       1.212681e+06                       0.000000
# 25%       1.250438e+06                       0.000000
# 50%       1.287844e+06                       0.000000
# 75%       1.325191e+06                       4.000000
# max       1.362605e+06                    9007.000000

# %% [markdown]
# # **Outlier detection**

# %%
numiric_value=df[['Number_Of_Students_On_The_Bus']]

fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(numiric_value)
plt.show()

# %% [markdown]
# ## Data Preprocessing
# This could include:
#
# * **Handle Missing Values**
#     * Impute missing values or drop them.
#
# * **Encode Categorical Variables**
#     * One-hot encoding
#     * Label encoding
#
# * **Scale and Normalize Data**
#     * Standardization (Z-score)
#     * Min-Max scaling
#
# * **Feature Engineering**
#     * Create new features
#     * Feature selection
#
# * **Handle Imbalanced Data**
#     * Oversampling
#     * Undersampling
#
# * **Handle Outliers**
#     * Remove outliers
#     * Transform outliers
#
# * **Remove Duplicates**
#     * Remove redundant or duplicate data
#
#
# And add more as needed!
#
# Please treat these as suggestions. Feel free to use your judgment for the rest.

# %% [markdown]
# # **Feature Engineering**

# %%
df['Occurred_On']=pd.to_datetime(df['Occurred_On'])
df['Created_On']=pd.to_datetime(df['Created_On'])
df['Informed_On']=pd.to_datetime(df['Informed_On'])
df['Last_Updated_On']=pd.to_datetime(df['Last_Updated_On'])

# %%
df['How_Long_Delayed']
# Out:
# 0          10MINUTES
# 1         25 MINUTES
# 2         15 MINUTES
# 3         10 minutes
# 4          10MINUTES
#              ...
# 147967         15-20
# 147968       20 MINS
# 147969     20-25MINS
# 147970           NaN
# 147971         45min
# Name: How_Long_Delayed, Length: 147972, dtype: object

# %%
df['How_Long_Delayed']=df['How_Long_Delayed'].str.replace('MINUTES',' ').str.strip().str.extract('(\d+)').astype(float)

# %% [markdown]
# #**Handle Outliers**
#
# Remove outliers
# Transform outliers

# %%
def remove_outlier(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

df = remove_outlier(df,'Number_Of_Students_On_The_Bus')

# %% [markdown]
# #**Handle Missing Values**
#
# Impute missing values or drop them.

# %%
df=df.drop('Busbreakdown_ID',axis=1)
df=df.drop('Incident_Number',axis=1)

# %%
df.replace(' ', pd.NA, inplace=True)
remove_unknown_other_na=df.columns
for column in remove_unknown_other_na:
    mode_value = df[column].replace(['Unknown', 'na', 'Other'], pd.NA).mode()[0]
    df[column] = df[column].replace(['Unknown', 'na', 'Other'], mode_value).fillna(mode_value)

# %%
df.isnull().sum()
# Out:
# School_Year                        0
# Run_Type                           0
# Bus_No                             0
# Route_Number                       0
# Reason                             0
# Schools_Serviced                   0
# Occurred_On                        0
# Created_On                         0
# Boro                               0
# Bus_Company_Name                   0
# How_Long_Delayed                   0
# Number_Of_Students_On_The_Bus      0
# Has_Contractor_Notified_Schools    0
# Has_Contractor_Notified_Parents    0
# Have_You_Alerted_OPT               0
# Informed_On                        0
# Last_Updated_On                    0
# Breakdown_or_Running_Late          0
# School_Age_or_PreK                 0
# dtype: int64

# %%
df.sample(5)
# Out:
#        School_Year           Run_Type   Bus_No Route_Number         Reason  \
# 119749   2016-2017  Special Ed AM Run     1273         R723  Heavy Traffic
# 4225     2015-2016  Special Ed AM Run  NI-2104         K017  Heavy Traffic
# 91240    2016-2017  Special Ed AM Run   NI1493         K228  Heavy Traffic
# 129610   2016-2017  Special Ed AM Run     1344         M450  Heavy Traffic
# 13448    2015-2016  Special Ed AM Run      V96         X669  Heavy Traffic
#
#        Schools_Serviced         Occurred_On          Created_On  \
# 119749            31463 2017-04-21 07:44:00 2017-04-21 07:48:00
# 4225              22206 2015-09-11 07:53:00 2015-09-11 11:06:00
# 91240             22350 2017-01-04 07:30:00 2017-01-04 07:32:00
# 129610            04001 2017-05-22 07:11:00 2017-05-22 07:12:00
# 13448             08269 2015-12-01 06:15:00 2015-12-01 06:17:00
#
#                  Boro           Bus_Company_Name  How_Long_Delayed  \
# 119749  Staten Island  HOYT TRANSPORTATION CORP.              20.0
# 4225         Brooklyn  NEW DAWN TRANSIT, LLC (B2              40.0
# 91240        Brooklyn  NEW DAWN TRANSIT, LLC (B2              35.0
# 129610      Manhattan  LEESEL TRANSP CORP (B2192              20.0
# 13448           Bronx  PIONEER TRANSPORTATION CO              15.0
#
#         Number_Of_Students_On_The_Bus Has_Contractor_Notified_Schools  \
# 119749                              2                             Yes
# 4225                                5                             Yes
# 91240                               9                             Yes
# 129610                              0                             Yes
# 13448                               0                             Yes
#
#        Has_Contractor_Notified_Parents Have_You_Alerted_OPT  \
# 119749                             Yes                   No
# 4225                               Yes                   No
# 91240                              Yes                   No
# 129610                             Yes                   No
# 13448                               No                   No
#
#                Informed_On     Last_Updated_On Breakdown_or_Running_Late  \
# 119749 2017-04-21 07:48:00 2017-04-21 07:48:39              Running Late
# 4225   2015-09-11 11:06:00 2015-09-11 11:17:35              Running Late
# 91240  2017-01-04 07:32:00 2017-01-04 07:32:16              Running Late
# 129610 2017-05-22 07:12:00 2017-05-22 07:12:40              Running Late
# 13448  2015-12-01 06:17:00 2015-12-01 06:17:38              Running Late
#
#        School_Age_or_PreK
# 119749         School-Age
# 4225           School-Age
# 91240          School-Age
# 129610         School-Age
# 13448          School-Age

# %% [markdown]
# #**Remove Duplicates**
#
# Remove redundant or duplicate data

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #**Scale and Normalize Data**
#
# Standardization (Z-score)
# Min-Max scaling

# %%
scaler = StandardScaler()
df[['How_Long_Delayed', 'Number_Of_Students_On_The_Bus']] = scaler.fit_transform(df[['How_Long_Delayed', 'Number_Of_Students_On_The_Bus']])

# %%
df[['How_Long_Delayed', 'Number_Of_Students_On_The_Bus']].sample()
# Out:
#        How_Long_Delayed  Number_Of_Students_On_The_Bus
# 33853         -0.023297                      -0.687535

# %% [markdown]
# #**Encode Categorical Variables**
#
# One-hot encoding
# Label encoding

# %%
le=LabelEncoder()

encoded_label=['Has_Contractor_Notified_Schools','Has_Contractor_Notified_Parents','Have_You_Alerted_OPT','Breakdown_or_Running_Late','School_Age_or_PreK']

for i in encoded_label:
  df[i]=le.fit_transform(df[i])

# %%
df[['Has_Contractor_Notified_Schools','Has_Contractor_Notified_Parents','Have_You_Alerted_OPT','Breakdown_or_Running_Late','School_Age_or_PreK']].sample()
# Out:
#         Has_Contractor_Notified_Schools  Has_Contractor_Notified_Parents  \
# 138933                                0                                0
#
#         Have_You_Alerted_OPT  Breakdown_or_Running_Late  School_Age_or_PreK
# 138933                     0                          1                   1

# %%
df.sample()
# Out:
#        School_Year  Run_Type Bus_No Route_Number         Reason  \
# 122605   2016-2017  Pre-K/EI   2110         VN-1  Heavy Traffic
#
#        Schools_Serviced         Occurred_On          Created_On   Boro  \
# 122605             C551 2017-05-01 07:00:00 2017-05-01 07:03:00  Bronx
#
#               Bus_Company_Name  How_Long_Delayed  \
# 122605  DON THOMAS BUSES, INC.         -0.031716
#
#         Number_Of_Students_On_The_Bus  Has_Contractor_Notified_Schools  \
# 122605                      -0.315319                                1
#
#         Has_Contractor_Notified_Parents  Have_You_Alerted_OPT  \
# 122605                                1                     0
#
#                Informed_On     Last_Updated_On  Breakdown_or_Running_Late  \
# 122605 2017-05-01 07:03:00 2017-05-01 07:03:46                          1
#
#         School_Age_or_PreK
# 122605                   0

# %% [markdown]
# #**Feature selection**

# %%
df=df[['How_Long_Delayed','Number_Of_Students_On_The_Bus','Has_Contractor_Notified_Schools','Has_Contractor_Notified_Parents','Have_You_Alerted_OPT','Breakdown_or_Running_Late','School_Age_or_PreK']]

# %% [markdown]
# ## Split the Dataset
# Next, split the dataset into training, validation, and testing sets.

# %%
x=df.drop('Breakdown_or_Running_Late',axis=1)
y=df['Breakdown_or_Running_Late']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

sm=SMOTE(random_state=42)

x_train,y_train=sm.fit_resample(x_train,y_train)

# %% [markdown]
# ## Building the ANN Model
# In this section, define the architecture of the ANN by specifying the number of layers, neurons, and activation functions.

# %%
model_ann = models.Sequential([
    layers.Dense(units=128,activation='relu',input_dim=x_train.shape[1],name='layer1'),
    layers.Dropout(0.7),
    layers.Dense(units=64,activation='relu',name='layer2'),
    layers.Dropout(0.7),
    layers.Dense(units=32,activation='relu',name="layer3"),
    layers.Dropout(0.7),
    layers.Dense(units=1,activation='sigmoid',name='outputlayer')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_ann.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                       │ (None, 128)                 │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer2 (Dense)                       │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer3 (Dense)                       │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ outputlayer (Dense)                  │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,265 (44.00 KB)
#  Trainable params: 11,265 (44.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile the Model
# Compile the ANN model by defining the optimizer, loss function, and evaluation metrics.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model_ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Training the Model
# Train the ANN model using the training data.

# %%
history=model_ann.fit(x_train,y_train,batch_size=20,epochs=100,callbacks=early_stopping,validation_split=0.2,verbose=2)
# Out:
# Epoch 1/100
# 7911/7911 - 19s - 2ms/step - accuracy: 0.8096 - loss: 0.3752 - val_accuracy: 0.9876 - val_loss: 0.3751
# Epoch 2/100
# 7911/7911 - 23s - 3ms/step - accuracy: 0.8125 - loss: 0.3709 - val_accuracy: 0.9924 - val_loss: 0.3937
# Epoch 3/100
# 7911/7911 - 44s - 6ms/step - accuracy: 0.8127 - loss: 0.3727 - val_accuracy: 0.9716 - val_loss: 0.3995
# Epoch 4/100
# 7911/7911 - 35s - 4ms/step - accuracy: 0.8156 - loss: 0.3651 - val_accuracy: 0.9858 - val_loss: 0.3986
# Epoch 5/100
# 7911/7911 - 20s - 3ms/step - accuracy: 0.8161 - loss: 0.3631 - val_accuracy: 0.9873 - val_loss: 0.4027
# Epoch 6/100
# 7911/7911 - 20s - 3ms/step - accuracy: 0.8159 - loss: 0.3643 - val_accuracy: 0.9875 - val_loss: 0.4205
# Epoch 7/100
# 7911/7911 - 17s - 2ms/step - accuracy: 0.8180 - loss: 0.3592 - val_accuracy: 0.9895 - val_loss: 0.4123
# Epoch 8/100
# 7911/7911 - 18s - 2ms/step - accuracy: 0.8153 - loss: 0.3650 - val_accuracy: 0.9891 - val_loss: 0.3798
# Epoch 9/100
# 7911/7911 - 22s - 3ms/step - accuracy: 0.8167 - loss: 0.3621 - val_accuracy: 0.9965 - val_loss: 0.3764
# Epoch 10/100
# 7911/7911 - 19s - 2ms/step - accuracy: 0.8183 - loss: 0.3578 - val_accuracy: 0.9960 - val_loss: 0.3574
# Epoch 11/100
# 7911/7911 - 18s - 2ms/step - accuracy: 0.8211 - loss: 0.3566 - val_accuracy: 0.9726 - val_loss: 0.4096
# Epoch 12/100
# 7911/7911 - 21s - 3ms/step - accuracy: 0.8169 - loss: 0.3635 - val_accuracy: 0.9961 - val_loss: 0.3856
# Epoch 13/100
# 7911/7911 - 23s - 3ms/step - accuracy: 0.8215 - loss: 0.3567 - val_accuracy: 0.9967 - val_loss: 0.3580
# Epoch 14/100
# 7911/7911 - 17s - 2ms/step - accuracy: 0.8206 - loss: 0.3580 - val_accuracy: 0.9960 - val_loss: 0.3895
# Epoch 15/100
# 7911/7911 - 20s - 3ms/step - accuracy: 0.8215 - loss: 0.3560 - val_accuracy: 0.9877 - val_loss: 0.3959
# Epoch 16/100
# 7911/7911 - 17s - 2ms/step - accuracy: 0.8212 - loss: 0.3574 - val_accuracy: 0.9965 - val_loss: 0.3763
# Epoch 17/100
# 7911/7911 - 18s - 2ms/step - accuracy: 0.8200 - loss: 0.3571 - val_accuracy: 0.9903 - val_loss: 0.3789
# Epoch 18/100
# 7911/7911 - 20s - 3ms/step - accuracy: 0.8218 - loss: 0.3584 - val_accuracy: 0.9899 - val_loss: 0.3897
# Epoch 19/100
# 7911/7911 - 20s - 3ms/step - accuracy: 0.8221 - loss: 0.3554 - val_accuracy: 0.9961 - val_loss: 0.3782
# Epoch 20/100
# 7911/7911 - 21s - 3ms/step - accuracy: 0.8218 - loss: 0.3548 - val_accuracy: 0.9969 - val_loss: 0.4656

# %% [markdown]
# ## Evaluate the Model
# Evaluate the performance of the model on the test set.

# %%
y_pred=(model_ann.predict(x_test)>0.55).astype("int32")
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.52      3366
#            1       1.00      0.75      0.86     24687
#
#     accuracy                           0.78     28053
#    macro avg       0.68      0.87      0.69     28053
# weighted avg       0.92      0.78      0.82     28053
#
# [[ 3350    16]
#  [ 6080 18607]]

# %% [markdown]
# ## Make Predictions
# Use the trained model to make predictions on new or unseen data.

# %% [markdown]
# ## Model Performance Visualization
# Visualize the performance metrics such as accuracy and loss over the epochs.

# %%
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')

plt.show()

# %%
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')

plt.show()

# %% [markdown]
# ## Save the Model
# Save the trained model for submission.

# %%
model_ann.save('weekly_5.keras')

# %% [markdown]
# ## Project Questions:
#
# 1. **Data Preprocessing**: Explain why you chose your specific data preprocessing techniques (e.g., normalization, encoding). How did these techniques help prepare the data for training the model?
# 2. **Model Architecture**: Describe the reasoning behind your model’s architecture (e.g., the number of layers, type of layers, number of neurons, and activation functions). Why did you believe this architecture was appropriate for the problem at hand?
# 3. **Training Process**: Discuss why you chose your batch size, number of epochs, and optimizer. How did these choices affect the training process? Did you experiment with different values, and what were the outcomes?
# 4. **Loss Function and Metrics**: Why did you choose the specific loss function and evaluation metrics? How do they align with the objective of the task (e.g., regression vs classification)?
# 5. **Regularization Techniques**: If you used regularization techniques such as dropout or weight decay, explain why you implemented them and how they influenced the model's performance.
# 6. **Model Evaluation**: Justify your approach to evaluating the model. Why did you choose the specific performance metrics, and how do they reflect the model's success in solving the task?
# 7. **Model Tuning (If Done)**: Describe any tuning you performed (e.g., hyperparameter tuning) and why you felt it was necessary. How did these adjustments improve model performance?
# 8. **Overfitting and Underfitting**: Analyze whether the model encountered any overfitting or underfitting during training. What strategies could you implement to mitigate these issues?

# %% [markdown]
# ### Answer Here:

# %% [markdown]
# Dropped id and Incident_Number (too many values). Fixed outliers and data type for How_Long_Delayed. Used StandardScaler() to boost model performance. Applied LabelEncoder() for data processing. Used SMOTE(random_state=42) for oversampling the minority class
